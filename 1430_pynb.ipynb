# %% [markdown]
# <a href="https://colab.research.google.com/github/varun1430/HU22CSEN0101430/blob/main/1430_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello, {name}! You are {age} years old.")
# Out:
# Enter your name: varun
# Enter your age: 20
# Hello, varun! You are 20 years old.
